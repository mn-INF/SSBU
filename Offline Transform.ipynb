# %%
import pandas as pd

df = pd.read_excel("Tourney Data.xlsx")

ol = df.loc[df['Offline'] == 1]

print(ol.info())

ol.to_excel("Offline Data.xlsx")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 517 entries, 100 to 619
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tournament    517 non-null    int64
#  1   Placement     517 non-null    int64
#  2   Participants  517 non-null    int64
#  3   DQ_Wins       517 non-null    int64
#  4   Winning_Sets  517 non-null    int64
#  5   Losing_Sets   517 non-null    int64
#  6   Games_Won     517 non-null    int64
#  7   Games_Lost    517 non-null    int64
#  8   Game_3+       517 non-null    int64
#  9   Sweeps        517 non-null    int64
#  10  Chars_Won     510 non-null    object
#  11  Chars_Lost    506 non-null    object
#  12  Chars_All     517 non-null    object
#  13  Tourney_Win   517 non-null    int64
#  14  Offline       517 non-null    int64
#  15  Top_8         517 non-null    int64
# dtypes: int64(13), object(3)
# memory usage: 68.7+ KB
# None
